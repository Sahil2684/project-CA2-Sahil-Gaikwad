# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahil2684/project-CA2-Sahil-Gaikwad/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/CPU.csv')
df.head()
# Out:
#                              cpuName    price  cpuMark  threadMark    TDP  \
# 0                      AMD EPYC 7763  7299.99    88338        2635  280.0
# 1                      AMD EPYC 7713  7060.00    85861        2727  225.0
# 2  AMD Ryzen Threadripper PRO 3995WX  6807.98    83971        2626  280.0
# 3       AMD Ryzen Threadripper 3990X  8399.69    81568        2569  280.0
# 4                      AMD EPYC 7643  5424.99    76455        2695  225.0
#
#    cores socket category
# 0     64    SP3   Server
# 1     64    SP3   Server
# 2     64  sWRX8  Desktop
# 3     64  sTRX4  Desktop
# 4     48    SP3   Server

# %%
list(df.columns)
# Out:
# ['cpuName',
#  'price',
#  'cpuMark',
#  'threadMark',
#  'TDP',
#  'cores',
#  'socket',
#  'category']

# %%
df.shape[0]
# Out:
# 1938

# %%
null_values=df.isnull().sum()
print('null values is csv file:')
print('null_values')
# Out:
# null values is csv file:
# null_values

# %%
df['category'].value_counts()
# Out:
# Desktop                     820
# Server                      634
# Laptop                      401
# Unknown                      38
# Mobile/Embedded              15
# Laptop, Mobile/Embedded       9
# Laptop, Server                7
# Desktop, Server               6
# Desktop, Laptop               4
# Desktop, Mobile/Embedded      2
# Server, Mobile/Embedded       2
# Name: category, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1938 entries, 0 to 1937
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cpuName     1938 non-null   object
#  1   price       1938 non-null   float64
#  2   cpuMark     1938 non-null   int64
#  3   threadMark  1938 non-null   int64
#  4   TDP         1938 non-null   float64
#  5   cores       1938 non-null   int64
#  6   socket      1938 non-null   object
#  7   category    1938 non-null   object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 121.2+ KB

# %%
df.describe()
# Out:
#              price       cpuMark   threadMark          TDP        cores
# count  1938.000000   1938.000000  1938.000000  1938.000000  1938.000000
# mean    445.124216   8129.245614  1677.188854    76.231115     5.614035
# std     912.749539  10857.937369   760.862707    46.758629     6.527148
# min       3.990000    159.000000   224.000000     4.000000     1.000000
# 25%      66.330000   1652.000000  1085.500000    44.000000     2.000000
# 50%     161.000000   3937.000000  1571.000000    65.000000     4.000000
# 75%     395.000000   9905.250000  2199.500000    95.000000     6.000000
# max    8978.000000  88338.000000  4317.000000   280.000000    64.000000

# %%
sns.countplot(x='category',data=df,palette='coolware')
plt.xlabel()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have your data in a DataFrame called 'df'

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a bar plot
sns.barplot(x='category', y='cpuMark', data=df, ci=None, palette='Set2')

# Set the title and labels
plt.title("CPU Mark by Category")
plt.xlabel("Category")
plt.ylabel("CPU Mark")

# Show the plot
plt.show()
# Out:
# <ipython-input-29-72810cc6eaa0>:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='category', y='cpuMark', data=df, ci=None, palette='Set2')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have your data in a DataFrame called 'df'

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a bar plot
ax = sns.barplot(x='category', y='cpuMark', data=df, ci=None, palette='Set2')

# Rotate the x-axis labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# Set the title and labels
plt.title("CPU Mark by Category")
plt.xlabel("Category")
plt.ylabel("CPU Mark")

# Show the plot
plt.show()
# Out:
# <ipython-input-30-268260a0330c>:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='category', y='cpuMark', data=df, ci=None, palette='Set2')
